# %%
import pandas as pd


df = pd.read_csv("../data/processed/steam_games_features.csv")


df["name"].duplicated().sum()
# Out:
# np.int64(107)

# %%
df[
    [
        "developer_previous_games",
        "developer_previous_success",
        "developer_previous_reception",
    ]
].describe()
# Out:
#        developer_previous_games  developer_previous_success  \
# count              44584.000000                44584.000000
# mean                   2.344002                    0.490189
# std                    6.971430                    0.876012
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    2.000000                    0.666667
# max                   98.000000                    3.000000
#
#        developer_previous_reception
# count                  44584.000000
# mean                       0.314559
# std                        0.387426
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.750000
# max                        1.000000

# %%
df['name'].duplicated().sum()
# Out:
# np.int64(107)

# %%
df[df["name"].duplicated(keep=False)][["name", "release_date", "main_developer"]].head(
    20
)
# Out:
#                                         name release_date  \
# 142                                   DOOM 3   2007-08-03
# 663   Tom Clancy's Splinter Cell Conviction™   2010-04-27
# 669   Tom Clancy's Splinter Cell Conviction™   2010-04-29
# 716                                Alter Ego   2010-08-03
# 804                                     RUSH   2010-12-03
# 1116                               Yesterday   2012-03-22
# 1289                                  DOOM 3   2012-10-15
# 1649                             Dark Matter   2013-10-17
# 1753      Tank Operations: European Campaign   2013-11-22
# 2247                            Secret Agent   2014-05-05
# 2285                               Ascendant   2014-05-13
# 2329                                Stranded   2014-05-20
# 2386                            Lost Marbles   2014-05-30
# 2509                               The House   2014-07-01
# 2681                  New York Bus Simulator   2014-08-06
# ...

# %%
df[df["main_developer"] == "Valve"][
    ["name", "release_year", "developer_previous_games"]
].head(15)
# Out:
#                                name  release_year  developer_previous_games
# 2                         Half-Life          1998                         0
# 3             Team Fortress Classic          1999                         1
# 5                    Counter-Strike          2000                         2
# 6                          Ricochet          2000                         3
# 8                Deathmatch Classic          2001                         4
# 12                    Day of Defeat          2003                         5
# 15   Counter-Strike: Condition Zero          2004                         6
# 16                Half-Life: Source          2004                         7
# 17           Counter-Strike: Source          2004                         8
# 18          Half-Life 2: Deathmatch          2004                         9
# 19                      Half-Life 2          2004                        10
# ...
